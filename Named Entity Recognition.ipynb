# %%
sentence="The Eiffel Tower was built from 1887 to 1889 by Gustave Eiffel, whose company specialized in building metal frameworks and structures."

# %%
import nltk 
words=nltk.word_tokenize(sentence)

# %%
tag_elements=nltk.pos_tag(words)

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sopan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\sopan\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\sopan\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\sopan\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
nltk.ne_chunk(tag_elements).draw()

# %%
# https://www.youtube.com/watch?v=ENLEjGozrio&t=6338s 1.51

# %%
import os
print("PYTHONPATH:", os.environ.get('PYTHONPATH'))
print("PATH:", os.environ.get('PATH'))
# Out:
# PYTHONPATH: C:\ProgramData\anaconda3;%PYTHONPATH%
# PATH: C:\Users\sopan\env-krish-naik\Scripts;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\system32\Wbem;C:\Python314\Scripts\;C:\Python314\;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\system32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\mongosh-2.3.9-win32-x64\mongosh-2.3.9-win32-x64\bin;C:\Program Files\dotnet\;C:\Program Files (x86)\LLVM\bin\;C:\Program Files\Go\bin;C:\Program Files\CMake\bin;c:\Users\sopan\AppData\Local\Programs\cursor\resources\app\bin;C:\ProgramData\chocolatey\bin;C:\Program Files\nodejs\;C:\Program Files\Git\cmd;C:\Program Files\Docker\Docker\resources\bin;C:\Users\sopan\AppData\Local\Programs\Python\Python311\Scripts\;C:\Users\sopan\AppData\Local\Programs\Python\Python311\;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\system32\Wbem;C:\Python314\Scripts\;C:\Python314\;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\system32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\mongosh-2.3.9-win32-x64\mongosh-2.3.9-win32-x64\bin;C:\Program Files\dotnet\;C:\Program Files (x86)\LLVM\bin\;C:\Program Files\Go\bin;C:\Program Files\CMake\bin;c:\Users\sopan\AppData\Local\Programs\cursor\resources\app\bin;C:\ProgramData\chocolatey\bin;C:\Program Files\nodejs\;C:\Program Files\Git\cmd;C:\Program Files\Docker\Docker\resources\bin;C:\Program Files\cursor\resources\app\bin;C:\Users\sopan\.rover\bin;C:\Program Files\MongoDB\Server\8.2\bin;C:\Users\sopan\AppData\Roaming\npm;C:\Program Files (x86)\MongoDB Atlas CLI\;C:\pgsql\bin;C:\msys64\mingw64\bin;C:\opencv\build\x;C:\mingw64\bin;C:\Users\sopan\AppData\Roaming\npm;C:\Program Files\Docker\Docker\resources\bin;C:\Users\sopan\AppData\Local\Programs\Microsoft VS Code\bin;C:\Users\sopan\AppData\Local\Programs\Microsoft VS Code Insiders\bin
